# %% [markdown]
# <a href="https://colab.research.google.com/github/jpedroleal2011-ctrl/PA-1C-grupo-A/blob/main/23_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int (input("digete um numero: "))
b = int (input("digete um numero: "))

if a> b:

 print(f"(a) maior que (b)>")

else:

  print(f"(b) maior que (a)3")
# Out:
# digete um numero: 4
# digete um numero: 55
# (b) maior que (a)

# %%
# escrever um programa que verifica se o usuario e maior de idade

nome = str (input("digite seu nome: "))
idade = int (input("digite sua idade: "))

if idade >= 18:

  print(f"{nome} voce e maior de idade")

else:

  print (f"{nome}voce e menor de idade")
# Out:
# digite seu nome: joao
# digite sua idade: 12
# voce e menor de idade

# %%
# escrever um programa que verifica se um numero e par ou impar


numero = int(input("Digite um número: "))


if numero % 2 == 0:
    print(f"O número {numero} é par")
else:
    print(f"O número {numero} é ímpar")
# Out:
# Digite um número: 4
# O número 4 é par

# %%
# escreva um programa que verica senha simples, senha == 1234, saida acesso

senha = 1234

senha_digitada = int (input("digite sua senha: "))

if senha == senha_digitada:
  print("acesso permitido")
else:
  print("acesso negado, digite novamente")

  senha_digitada = int (input("digite sua senha: "))

if senha_digitada == senha_digitada:
  print("acesso permitido")
else:
  print("acesso negado, digite novamente")
# Out:
# digite sua senha: 8967
# acesso negado, digite novamente
# digite sua senha: 1234
# acesso permitido

# %%
# escrever um programa que verifica se um numero e maior que dez

numero = int(input("Digite um numero: "))

if  numero > 10:
  print(f"o numero e maior que 10")
else:
  print(f"o numero e menor que 10")
# Out:
# Digite um numero: 5
# o numero e menor que 10

# %%
# escreva um programa que:
# peca o valor da compra
# se o valor for maior que 100, aplique um desconto de 10%
# se nao mostre o valor normal

valor  = float(input("Digite o valor da compra: "))

if valor >= 100:
  desconto =valor * 0.10
  print(f"{valor} voce ganhou um desconto  de 10%")
  print(f"valor com desconto: {valor - desconto}")
else:
  print(f"valor sem desconto: ")
# Out:
# Digite o valor da compra: 120
# 120.0 voce ganhou um desconto  de 10%
# valor com desconto: 108.0

# %%
# escrever um programa que o aluno digita 04 nota dos bimestre e o programa a media e  mostra ana saida se o aluno foi aprovado, recuperacao ou reprovado

nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
nota4 = float(input("Digite a quarta nota: "))
media = (nota1 + nota2 + nota3 + nota4) / 4

if media >= 7:

  print (f"voce foi aprtovado sua media foi {media}")

else:
  if media >= 5:
    print (f"voce esta de recuperacao sua media foi {media}")

else:

  print(f"voce foi reprovado sua media foi:{media}")
# Out:
#   File "/tmp/ipykernel_9282/1007327327.py", line 17
#     else:
#     ^
# SyntaxError: invalid syntax
