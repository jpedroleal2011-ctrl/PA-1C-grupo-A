# %% [markdown]
# <a href="https://colab.research.google.com/github/jpedroleal2011-ctrl/PA-1C-grupo-A/blob/main/atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#criar um programa que leia a idade

idade = int(input("digite sua idade:     "))
if idade <=17:
    print("você é menor de idade")
elif idade >=18:
    print("você é adulto")
elif idade <= 60:
    print("você é idoso")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 #criar um programa que leia a idade
# ----> 3 idade = int(input("digite sua idade:     "))
#       4 if idade <=17:
#       5     print("você é menor de idade")
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# JOAO PEDRO LEAL DE MORAES E EDUARDO SILVA GOMES

# %%
#calculo de desconto

compra = float(input("digite o valor da sua compra:"))


if compra >= 101:
  desconto = compra * 0.10
  print(f"{compra} voce ganhou um desconto  de 10%")
  print(f"compra com desconto: {compra - desconto}")
elif compra >= 500:
  desconto = compra * 0.20
  print(f"{compra} voce ganhou um desconto  de 20%")
  print(f"compra com desconto: {compra - desconto}")
else:
  print(f"compra sem desconto: ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 #calculo de desconto
# ----> 3 compra = float(input("digite o valor da sua compra:"))
#       6 if compra >= 101:
#       7   desconto = compra * 0.10
#
# ValueError: could not convert string to float: ''

# %%
#verificação de triangulo

a=int(input("digite o primeiro lado: "))
b=int(input("digite o segundo lado: "))
c=int(input("digite o terceiro lado: "))
print("")

if a+b>c and a+c>b and b+c>a:
    print("é um triangulo")

if a+b<c or a+c<b or b+c<a:
    print("não é um triangulo")

# %%
#sistema de jogo
vida = int(input(" digete o nivel da sua energia"))
if vida ==0:
    print("morto")
elif vida >=1  <=30:
    print("critico")
elif vida >=31 <=70:
    print("normal")
else:
    print("saudavel")

# %%
#media escolar

nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
nota4 = float(input("Digite a quarta nota: "))
media = (nota1 + nota2 + nota3 + nota4) / 4

if media >= 7:

  print (f"voce foi aprtovado sua media foi {media}")


elif  media >= 5:
    print (f"voce esta de recuperacao sua media foi {media}")

else:

  print(f"voce foi reprovado sua media foi:{media}")

# %%
salario = 1000
pontuação = int(input("digete sua pontuação:  "))
if pontuação <5:
    print(você nao tem bonus)
elif pontuação >=5 <=7:
bonus = salario * 0.05
  print(f"{salario} voce ganhou 5% de bonus")
  print(f"salario com desconto:{salario+bonus}")
elif pontuação 8 or 9:
bonus = salario * 0.10
    print(f"{salario} voce ganhou um bonus de 10%")
    print(f"salario com desconto:{salario+desconto}")
